# %% [markdown]
# <h1>Using the Last Fm API to extract data and analyzing it with Python. (Part 1)</h1>

# %% [markdown]
# As you already know, Last Fm is a service (kind of a social network) to store your music listening activity, that is called *scrobbling*, and I have been using that service since late 2008. The goal of this project is to create new visualization, Last Fm itself shows some nice charts and numbers but I wanted a little more.
#
# In this first part I'm going to show you how to extract the data and clean it using Python, but please keep in mind that **I'm new in the data analytics/science world and English is not my native language. I'm still learning. If you could give  me your feedback about these two topics, I would really appreciate it.** :hugs:
#
# <h2> :nerd_face:  Understating the API.</h2>
#
# Last Fm offer a very simple API. It doesn't need authentication and the payload is very simple. But they ask you some things:
#
# * :space_invader: To use an identifiable User-Agent header on all requests.
# * :space_invader: To be reasonable, don't make an excessive number of calls.
# * :space_invader: And of course, the assumption that if you use the API you are accepting its terms of service.
#
# Link: https://www.last.fm/api/intro
#
# You can create an API KEY https://www.last.fm/api/account/create or find the API at http://ws.audioscrobbler.com/2.0/
#
# The API have some methods like album, artist, users, playlist. Each one has some customizable options. In this post I'm going to use two: recent tracks and loved tracks.
#
# <h2> :writing_hand: Building the script</h2>
#
# I'm going to do a lot of request with the same user, key and user-agent, so the best way to do it is to create a function.

# %%
import requests
API_KEY = '62db2e8a92143737f526939ea0b7471c'
USER_AGENT = 'Mozilla/5.0'
USERNAME = 'chmedina'
def lastfm_get(payload):
    headers = {'user-agent': USER_AGENT}
    url = 'https://ws.audioscrobbler.com/2.0/'
    payload['user'] = USERNAME
    payload['api_key'] = API_KEY
    payload['format'] = 'json'

    response = requests.get(url, headers=headers, params=payload)
    return response

# %% [markdown]
# If the function is OK, the response should be a 200 code:
#
# HTTP Status codes: https://developer.mozilla.org/es/docs/Web/HTTP/Status

# %%
r = lastfm_get({
    'method': 'user.getrecenttracks'
})
r.status_code
# Out:
# 200

# %% [markdown]
# The response is something like this:

# %%
import json
def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)
jprint(r.json())
# Out:
# {
#     "recenttracks": {
#         "@attr": {
#             "page": "1",
#             "perPage": "50",
#             "total": "239915",
#             "totalPages": "4799",
#             "user": "chmedina"
#         },
#         "track": [
#             {
#                 "@attr": {
#                     "nowplaying": "true"
#                 },
#                 "album": {
#                     "#text": "Aqualung",
#                     "mbid": "0e4c0fce-a20d-4fa5-930f-c77028582cb5"
#                 },
#                 "artist": {
#                     "#text": "Jethro Tull",
#                     "mbid": ""
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/726ad6b833be42e0bdcd8ccbc5b68aac.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/726ad6b833be42e0bdcd8ccbc5b68aac.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/726ad6b833be42e0bdcd8ccbc5b68aac.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/726ad6b833be42e0bdcd8ccbc5b68aac.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "Aqualung - Steven Wilson Stereo Remix",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Jethro+Tull/_/Aqualung+-+Steven+Wilson+Stereo+Remix"
#             },
#             {
#                 "album": {
#                     "#text": "In The Court Of The Crimson King (Expanded & Remastered Original Album Mix)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "King Crimson",
#                     "mbid": ""
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 21:04",
#                     "uts": "1629925481"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "The Court of the Crimson King - Including \"The Return of the Fire Witch\" and \"The Dance of the Puppets\"",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/King+Crimson/_/The+Court+of+the+Crimson+King+-+Including+%22The+Return+of+the+Fire+Witch%22+and+%22The+Dance+of+the+Puppets%22"
#             },
#             {
#                 "album": {
#                     "#text": "Close to the Edge",
#                     "mbid": "0196b507-f001-4335-9b03-d1f5711d75ee"
#                 },
#                 "artist": {
#                     "#text": "Yes",
#                     "mbid": ""
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 20:45",
#                     "uts": "1629924359"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/85ee7d192fb14b6ccb57676f75b889fc.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/85ee7d192fb14b6ccb57676f75b889fc.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/85ee7d192fb14b6ccb57676f75b889fc.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/85ee7d192fb14b6ccb57676f75b889fc.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "Close to the Edge (i. The Solid Time of Change, ii. Total Mass Retain, iii. I Get up I Get Down, iv. Seasons of Man) - 2003 Remaster",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Yes/_/Close+to+the+Edge+(i.+The+Solid+Time+of+Change,+ii.+Total+Mass+Retain,+iii.+I+Get+up+I+Get+Down,+iv.+Seasons+of+Man)+-+2003+Remaster"
#             },
#             {
#                 "album": {
#                     "#text": "Selling England by the Pound",
#                     "mbid": "07909ece-f088-455c-9f01-59fb608aa22c"
#                 },
#                 "artist": {
#                     "#text": "Genesis",
#                     "mbid": ""
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 20:36",
#                     "uts": "1629923783"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/1d20439b8467234f5e083884792cc5c6.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/1d20439b8467234f5e083884792cc5c6.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/1d20439b8467234f5e083884792cc5c6.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/1d20439b8467234f5e083884792cc5c6.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "Firth Of Fifth - Remastered 2008",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Genesis/_/Firth+Of+Fifth+-+Remastered+2008"
#             },
#             {
#                 "album": {
#                     "#text": "The Condensed 21st Century Guide to King Crimson (1969 - 2003)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "King Crimson",
#                     "mbid": "b38225b8-8e5f-42aa-bcdc-7bae5b5bdab3"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 20:28",
#                     "uts": "1629923339"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "01dd4035-1d49-4182-b8b6-73e57b32d324",
#                 "name": "21st Century Schizoid Man",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/King+Crimson/_/21st+Century+Schizoid+Man"
#             },
#             {
#                 "album": {
#                     "#text": "Meddle",
#                     "mbid": "08323c03-f4fb-4f83-a02a-232a966c99d0"
#                 },
#                 "artist": {
#                     "#text": "Pink Floyd",
#                     "mbid": "83d91898-7763-47d7-b03b-b92132375c47"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 20:05",
#                     "uts": "1629921924"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/55dc29cfc3264ee3cee981181ddead2a.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/55dc29cfc3264ee3cee981181ddead2a.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/55dc29cfc3264ee3cee981181ddead2a.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/55dc29cfc3264ee3cee981181ddead2a.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "009e0c40-1f73-3e14-8464-f6c0c8ee70d8",
#                 "name": "Echoes",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Pink+Floyd/_/Echoes"
#             },
#             {
#                 "album": {
#                     "#text": "Original Masters",
#                     "mbid": "0e17249e-8f35-4fff-8748-1bff14dd0a1f"
#                 },
#                 "artist": {
#                     "#text": "Jethro Tull",
#                     "mbid": ""
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 19:59",
#                     "uts": "1629921546"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/83ac1cef86304541c5168d31b521d35d.jpg",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/83ac1cef86304541c5168d31b521d35d.jpg",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/83ac1cef86304541c5168d31b521d35d.jpg",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/83ac1cef86304541c5168d31b521d35d.jpg",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "Thick As A Brick - Edit #1",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Jethro+Tull/_/Thick+As+A+Brick+-+Edit+%231"
#             },
#             {
#                 "album": {
#                     "#text": "Red (Expanded & Remastered Original Album Mix)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "King Crimson",
#                     "mbid": "b38225b8-8e5f-42aa-bcdc-7bae5b5bdab3"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 19:46",
#                     "uts": "1629920800"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "0089be83-471d-4c36-9fb2-4c821f58dc80",
#                 "name": "Starless",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/King+Crimson/_/Starless"
#             },
#             {
#                 "album": {
#                     "#text": "2112 (Remastered)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "Rush",
#                     "mbid": "abddd730-21df-49eb-b594-ff32c51ef1d6"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 19:26",
#                     "uts": "1629919564"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/692bc269c47ed077a348b3d38d629fbd.jpg",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/692bc269c47ed077a348b3d38d629fbd.jpg",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/692bc269c47ed077a348b3d38d629fbd.jpg",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/692bc269c47ed077a348b3d38d629fbd.jpg",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "2112: Overture / The Temples Of Syrinx / Discovery / Presentation / Oracle / Soliloquy / Grand Finale - Medley",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Rush/_/2112:+Overture+%2F+The+Temples+Of+Syrinx+%2F+Discovery+%2F+Presentation+%2F+Oracle+%2F+Soliloquy+%2F+Grand+Finale+-+Medley"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": ""
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 01:40",
#                     "uts": "1629855622"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "Hunting High And Low - Live",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Hunting+High+And+Low+-+Live"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 01:33",
#                     "uts": "1629855185"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "0de8c07e-c3b8-34c8-9cf3-bf3f89a2f353",
#                 "name": "Black Diamond - Live",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Black+Diamond+-+Live"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": ""
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 01:27",
#                     "uts": "1629854847"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "Paradise - Live",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Paradise+-+Live"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 01:22",
#                     "uts": "1629854571"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "31019e69-657a-4cf2-977b-cc8bbbbd7760",
#                 "name": "Forever - Live",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Forever+-+Live"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 01:08",
#                     "uts": "1629853724"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "Destiny/Fantasia - Live",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Destiny%2FFantasia+-+Live"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 01:00",
#                     "uts": "1629853251"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "Soul Of A Vagabond - Live",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Soul+Of+A+Vagabond+-+Live"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:53",
#                     "uts": "1629852828"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "",
#                 "name": "Papillon - French Version",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Papillon+-+French+Version"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:48",
#                     "uts": "1629852539"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "415159a4-50cc-4418-bf4d-46e65166335b",
#                 "name": "Ride Like The Wind",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Ride+Like+The+Wind"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:43",
#                     "uts": "1629852201"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "6324580e-cd9f-443c-beec-d19856a4a1ed",
#                 "name": "Into Deep Blue",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Into+Deep+Blue"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:38",
#                     "uts": "1629851910"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "0712af82-c8a2-3eeb-b317-fe39be07efd0",
#                 "name": "Run Away",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Run+Away"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:33",
#                     "uts": "1629851607"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "20f31536-8b03-37e8-b8bb-bbc2fd944ebe",
#                 "name": "Liberty",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Liberty"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:27",
#                     "uts": "1629851254"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "1e6277aa-08fa-3f8c-bb7d-ea627a9b5562",
#                 "name": "Dreamweaver",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Dreamweaver"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:22",
#                     "uts": "1629850963"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "2358ce1f-23b6-446c-b7d2-891e07e83298",
#                 "name": "Luminous",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Luminous"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:17",
#                     "uts": "1629850625"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "08b661a6-074f-3a7b-b78d-6a63852bdf9d",
#                 "name": "Know The Difference",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Know+The+Difference"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:10",
#                     "uts": "1629850227"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "3ae1b55e-cac8-4153-bb7b-5b71e468a274",
#                 "name": "Awaken The Giant",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Awaken+The+Giant"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "25 Aug 2021, 00:04",
#                     "uts": "1629849858"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "63d3913b-8068-34f9-822e-fd256ddca80f",
#                 "name": "Season of faith's perfection",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Season+of+faith%27s+perfection"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 23:59",
#                     "uts": "1629849567"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "17dbf19f-63cb-3d46-9a55-a6e778959a4d",
#                 "name": "I'm Still Alive",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/I%27m+Still+Alive"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 23:54",
#                     "uts": "1629849263"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "03e08009-239a-44d8-b8bf-0b99a30fc868",
#                 "name": "I Walk To My Own Song",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/I+Walk+To+My+Own+Song"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 23:47",
#                     "uts": "1629848864"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "0e979d3d-e801-4a46-8df7-e80cb860d03d",
#                 "name": "Alpha & Omega",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Alpha+&+Omega"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 23:40",
#                     "uts": "1629848452"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "051fe27f-3425-4ea2-b4ff-e3d1c1b88212",
#                 "name": "A Drop In The Ocean",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/A+Drop+In+The+Ocean"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 23:28",
#                     "uts": "1629847731"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/28196b94c6494483c4b52baa9739aa48.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "1955b717-427a-4c24-9ad7-fc104827f0df",
#                 "name": "Elements",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Elements"
#             },
#             {
#                 "album": {
#                     "#text": "Elements, Pt. 1 & 2 (Complete Edition)",
#                     "mbid": "31190615-d6d6-4855-afec-8fb99f98ae22"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
# ...
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "14f6e4ba-9faa-3b7d-b33e-9bbd30d85840",
#                 "name": "Holy Light",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Holy+Light"
#             },
#             {
#                 "album": {
#                     "#text": "Visions (Original Version)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 22:13",
#                     "uts": "1629843220"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "10a27dca-58bd-42a9-9208-6396b681cca8",
#                 "name": "The Abyss of Your Eyes",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/The+Abyss+of+Your+Eyes"
#             },
#             {
#                 "album": {
#                     "#text": "Visions (Original Version)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 22:07",
#                     "uts": "1629842875"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "097570be-8022-418f-ac9b-59f5c8e805cc",
#                 "name": "Legions",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Legions"
#             },
#             {
#                 "album": {
#                     "#text": "Visions (Original Version)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 22:01",
#                     "uts": "1629842507"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "41d79998-f424-3cd8-a67b-10023c84ecad",
#                 "name": "Before the Winter",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Before+the+Winter"
#             },
#             {
#                 "album": {
#                     "#text": "Visions (Original Version)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 21:55",
#                     "uts": "1629842145"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "07b6a156-30e8-36dd-a8f4-87ff868a584e",
#                 "name": "Forever Free",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Forever+Free"
#             },
#             {
#                 "album": {
#                     "#text": "Visions (Original Version)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 21:50",
#                     "uts": "1629841804"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "02f005fd-8b3e-35c6-a0b1-047d46ff4245",
#                 "name": "Black Diamond",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Black+Diamond"
#             },
#             {
#                 "album": {
#                     "#text": "Visions (Original Version)",
#                     "mbid": ""
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 21:44",
#                     "uts": "1629841453"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/d06702bb730f0462d95498ff73e99a77.jpg",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "03c51597-1890-36d2-a203-c33cda276fd4",
#                 "name": "The Kiss of Judas",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/The+Kiss+of+Judas"
#             },
#             {
#                 "album": {
#                     "#text": "Infinite",
#                     "mbid": "0c653129-9b26-35b1-8871-e845ad97f0cf"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 21:39",
#                     "uts": "1629841157"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "0bb35818-5fd8-3064-8c67-a42782a06f8d",
#                 "name": "Why Are We Here",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Why+Are+We+Here"
#             },
#             {
#                 "album": {
#                     "#text": "Infinite",
#                     "mbid": "0c653129-9b26-35b1-8871-e845ad97f0cf"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 21:36",
#                     "uts": "1629841006"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "22598fea-6c90-45d7-9b20-82ecdd164bfc",
#                 "name": "Celestial Dream",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Celestial+Dream"
#             },
#             {
#                 "album": {
#                     "#text": "Infinite",
#                     "mbid": "0c653129-9b26-35b1-8871-e845ad97f0cf"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 21:27",
#                     "uts": "1629840443"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "05110260-28d8-3705-b489-4f8ac985d891",
#                 "name": "Infinity",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Infinity"
#             },
#             {
#                 "album": {
#                     "#text": "Infinite",
#                     "mbid": "0c653129-9b26-35b1-8871-e845ad97f0cf"
#                 },
#                 "artist": {
#                     "#text": "Stratovarius",
#                     "mbid": "c3d6fdd5-67c5-453e-87e3-d17a00a52879"
#                 },
#                 "date": {
#                     "#text": "24 Aug 2021, 21:22",
#                     "uts": "1629840138"
#                 },
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/9b945a514da04f92cf4ea18d4ac23e8f.png",
#                         "size": "extralarge"
#                     }
#                 ],
#                 "mbid": "2573921c-a8a7-32e4-81c1-75bd97fecc7e",
#                 "name": "Freedom",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Stratovarius/_/Freedom"
#             }
#         ]
#     }
# }

# %% [markdown]
# <h2> :open_book: Paginated Data</h2>
#
# Depending on how many songs you have or need to download, the response could be many pages long. As you can see, my user has 4799 where 50 results are shown per page.
#
# In order to work with this, you must configure an script for paging:

# %%
results = []
page = 1
total_pages = 10
while page > total_pages:
    r = request.get("endpoint_url", params={"page": page})
    results.append(r.json())
    page += 1

# %% [markdown]
# In the example total_pages = 10 because I wanted to do a short request. That number is going to change.
#
# And also, import the 'time' module to make the requests with a gap between each one and don't get your IP banned.

# %%
import time

print("one")
time.sleep(1)
print("two")
# Out:
# one
# two

# %% [markdown]
# One more  thing, this is going to be a large amount of data and if your code break you will lose all. :poop: Please install the request cache module.

# %%
pip install requests-cache
# Out:
# Requirement already satisfied: requests-cache in /home/chmedina/anaconda3/lib/python3.8/site-packages (0.7.4)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /home/chmedina/anaconda3/lib/python3.8/site-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: pyyaml>=5.4 in /home/chmedina/anaconda3/lib/python3.8/site-packages (from requests-cache) (5.4.1)
# Requirement already satisfied: attrs<22.0,>=21.2 in /home/chmedina/anaconda3/lib/python3.8/site-packages (from requests-cache) (21.2.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in /home/chmedina/anaconda3/lib/python3.8/site-packages (from requests-cache) (2.0.1)
# Requirement already satisfied: requests<3.0,>=2.17 in /home/chmedina/anaconda3/lib/python3.8/site-packages (from requests-cache) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chmedina/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.17->requests-cache) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/chmedina/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.17->requests-cache) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/chmedina/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.17->requests-cache) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/chmedina/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.17->requests-cache) (1.26.4)
# Requirement already satisfied: six in /home/chmedina/anaconda3/lib/python3.8/site-packages (from url-normalize<2.0,>=1.4->requests-cache) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h2> :round_pushpin: The final script is this:</h2>
#
# This will take time depending on the amount of data and the time.sleep settings

# %%
import time
from IPython.core.display import clear_output
import requests_cache
requests_cache.install_cache()
responses = []
page = 1
total_pages = 9999 
while page <= total_pages:
    payload = {
        'method': 'user.getrecenttracks',
        'limit': 500,
        'page': page,
    }
    print("Requesting page {}/{}".format(page, total_pages))
    clear_output(wait = True)
    response = lastfm_get(payload)

    if response.status_code != 200:
        print(response.text)
        break

    page = int(response.json()['recenttracks']['@attr']['page'])
    total_pages = int(response.json()['recenttracks']['@attr']['totalPages'])

    responses.append(response)

    if not getattr(response, 'from_cache', False):
        time.sleep(0.5)

    page += 1
# Out:
# Requesting page 480/480

# %% [markdown]
# <h2>:panda_face: Using Pandas to clean the data</h2>

# %%
import pandas as pd

r0 = responses[1]
r0_json = r0.json()
r0_track = r0_json['recenttracks']['track']
r0_df = pd.DataFrame(r0_track)
r0_df.head()
# Out:
#                                               artist  \
# 0  {'mbid': 'c147b96e-3428-4604-9b6c-d931f980f684...
# 1  {'mbid': '1136bc83-44bf-4fd5-b036-9067a30b3a75...
# 2  {'mbid': '1136bc83-44bf-4fd5-b036-9067a30b3a75...
# 3  {'mbid': '1932f5b6-0b7b-4050-b1df-833ca89e5f44...
# 4                {'mbid': '', '#text': 'Seedpicker'}
#
#                                                album  \
# 0  {'mbid': '188d704b-678d-499d-b488-516a7247cc01...
# 1            {'mbid': '', '#text': 'Smile of Tears'}
# 2  {'mbid': 'd62f8969-3f38-4df0-8556-a14cfe87c1e6...
# 3  {'mbid': '34d13866-e51b-410f-8c69-2a884f8031da...
# 4         {'mbid': '', '#text': 'Virginia Rhapsody'}
#
#                                                image streamable  \
# 0  [{'size': 'small', '#text': 'https://lastfm.fr...          0
# 1  [{'size': 'small', '#text': 'https://lastfm.fr...          0
# 2  [{'size': 'small', '#text': 'https://lastfm.fr...          0
# 3  [{'size': 'small', '#text': 'https://lastfm.fr...          0
# 4  [{'size': 'small', '#text': 'https://lastfm.fr...          0
#
#                                                 date  \
# 0  {'uts': '1628444107', '#text': '08 Aug 2021, 1...
# 1  {'uts': '1628443611', '#text': '08 Aug 2021, 1...
# 2  {'uts': '1628443406', '#text': '08 Aug 2021, 1...
# 3  {'uts': '1628442796', '#text': '08 Aug 2021, 1...
# 4  {'uts': '1628442429', '#text': '08 Aug 2021, 1...
#
#                                                  url                   name  \
# 0  https://www.last.fm/music/Oceansize/_/Music+Fo...      Music For A Nurse
# 1  https://www.last.fm/music/Aisles/_/Smile+of+Tears         Smile of Tears
# 2  https://www.last.fm/music/Aisles/_/The+Poet,+P...  The Poet, Pt. I: Dusk
# 3        https://www.last.fm/music/Marillion/_/Power                  Power
# 4  https://www.last.fm/music/Seedpicker/_/Power+Down             Power Down
#
#                                    mbid
# 0  713c0038-737f-3d76-a488-3c11cadac8a1
# 1  9d52ae3e-65f8-49f0-b075-6d41e507e932
# 2
# 3  0aedae8c-9350-46c5-8bb2-f1d422913b81
# 4

# %% [markdown]
# The .json file has some columns that we don't need. And the columns album, artist and date have the 'mbid' field and we don't need it either.
#
# There are two options:
#
# * Use pandas to select the #text field.
# * Format that as string and replace it.
#
# I choose the second option. I did this in parts for a better understanding:
#
# Drop the columns we don't need:

# %%
r0_df= r0_df.drop('image', axis=1)
r0_df= r0_df.drop('streamable', axis=1)
r0_df= r0_df.drop('url', axis=1)
r0_df= r0_df.drop('mbid', axis=1)
r0_df.head()
# Out:
#                                               artist  \
# 0  {'mbid': 'c147b96e-3428-4604-9b6c-d931f980f684...
# 1  {'mbid': '1136bc83-44bf-4fd5-b036-9067a30b3a75...
# 2  {'mbid': '1136bc83-44bf-4fd5-b036-9067a30b3a75...
# 3  {'mbid': '1932f5b6-0b7b-4050-b1df-833ca89e5f44...
# 4                {'mbid': '', '#text': 'Seedpicker'}
#
#                                                album  \
# 0  {'mbid': '188d704b-678d-499d-b488-516a7247cc01...
# 1            {'mbid': '', '#text': 'Smile of Tears'}
# 2  {'mbid': 'd62f8969-3f38-4df0-8556-a14cfe87c1e6...
# 3  {'mbid': '34d13866-e51b-410f-8c69-2a884f8031da...
# 4         {'mbid': '', '#text': 'Virginia Rhapsody'}
#
#                                                 date                   name
# 0  {'uts': '1628444107', '#text': '08 Aug 2021, 1...      Music For A Nurse
# 1  {'uts': '1628443611', '#text': '08 Aug 2021, 1...         Smile of Tears
# 2  {'uts': '1628443406', '#text': '08 Aug 2021, 1...  The Poet, Pt. I: Dusk
# 3  {'uts': '1628442796', '#text': '08 Aug 2021, 1...                  Power
# 4  {'uts': '1628442429', '#text': '08 Aug 2021, 1...             Power Down

# %% [markdown]
# Set the the columns album, artist and date as a string:

# %%
r0_df['artist'] = r0_df.artist.astype(str)
r0_df['album'] = r0_df.album.astype(str)
r0_df['date'] = r0_df.date.astype(str)
r0_df.head()

# %% [markdown]
# Split the strings:

# %%
r0_df[['mbid2','new_artist']]=r0_df['artist'].str.split("#text':", n = 1, expand = True)
r0_df= r0_df.drop('mbid2', axis=1)
r0_df= r0_df.drop('artist', axis=1)
r0_df[['mbid3','new_album']]=r0_df['album'].str.split("#text':", n = 1, expand = True)
r0_df= r0_df.drop('mbid3', axis=1)
r0_df= r0_df.drop('album', axis=1)
r0_df[['uts','new_date']]=r0_df['date'].str.split("#text':", n = 1, expand = True)
r0_df= r0_df.drop('date', axis=1)
r0_df.head()
# Out:
#                     name      new_artist                      new_album  \
# 0      Music For A Nurse    'Oceansize'}      'Everyone Into Position'}
# 1         Smile of Tears       'Aisles'}              'Smile of Tears'}
# 2  The Poet, Pt. I: Dusk       'Aisles'}                      'Hawaii'}
# 3                  Power    'Marillion'}   "Sounds That Can't Be Made"}
# 4             Power Down   'Seedpicker'}           'Virginia Rhapsody'}
#
#                        uts                new_date
# 0  {'uts': '1628444107', '   '08 Aug 2021, 17:35'}
# 1  {'uts': '1628443611', '   '08 Aug 2021, 17:26'}
# 2  {'uts': '1628443406', '   '08 Aug 2021, 17:23'}
# 3  {'uts': '1628442796', '   '08 Aug 2021, 17:13'}
# 4  {'uts': '1628442429', '   '08 Aug 2021, 17:07'}

# %% [markdown]
# The final steps are to remove the '}' characters and save it in a .csv file if you like. For my project I'm going to use four users, each one with  the scrobbled and loved tracks. At the end I will have eight csv files.
#
# In the part 2 I'm going to use Python for data visualization.   :paw_prints:
#
# To write this post I read the Dataquest blog https://www.dataquest.io/. That's where I learned the process. If you have questions with any procedure shown here, please go to their blog post https://www.dataquest.io/blog/last-fm-api-python/ where Celeste Grupman explain it in more detail.
#
# Thanks for reading, and remember I'm new in the data analytics/science world and English is not my native language. I'm still learning :student:. If you could give me your feedback about these two topics, I would really appreciate it. :bowing_man:
#
# Carlos Medina
